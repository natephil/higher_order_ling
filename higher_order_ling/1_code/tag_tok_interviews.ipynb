# %%
import nltk
import pandas as pd
import numpy as np

# %%
# set each interview block equal to a variable name
EC156_B8 = open("/Users/nathancahn/higher_order_ling/0_data/EC156_B8_interview.txt")
EC156_B9 = open("/Users/nathancahn/higher_order_ling/0_data/EC156_B9.txt")
EC156_B22 = open("/Users/nathancahn/higher_order_ling/0_data/EC156_B22.txt")
EC156_B25 = open("/Users/nathancahn/higher_order_ling/0_data/EC156_B25.txt")
EC156_B27 = open("/Users/nathancahn/higher_order_ling/0_data/EC156_B27.txt")
EC156_B32 = open("/Users/nathancahn/higher_order_ling/0_data/EC156_B32.txt")
EC156_B37 = open("/Users/nathancahn/higher_order_ling/0_data/EC156_B37.txt")
EC156_B38 = open("/Users/nathancahn/higher_order_ling/0_data/EC156_B38.txt")
EC156_B46 = open("/Users/nathancahn/higher_order_ling/0_data/EC156_B46.txt")
EC156_B55 = open("/Users/nathancahn/higher_order_ling/0_data/EC156_B55.txt")
EC156_B56 = open("/Users/nathancahn/higher_order_ling/0_data/EC156_B56.txt")
EC156_B67 = open("/Users/nathancahn/higher_order_ling/0_data/EC156_B67.txt")

EC159_B3 = open("/Users/nathancahn/higher_order_ling/0_data/EC159_B3.txt")
EC159_B17 = open("/Users/nathancahn/higher_order_ling/0_data/EC159_B17.txt")

EC166_B9 = open("/Users/nathancahn/higher_order_ling/0_data/EC166_B9.txt")
EC166_B11 = open("/Users/nathancahn/higher_order_ling/0_data/EC166_B11.txt")
EC166_B14 = open("/Users/nathancahn/higher_order_ling/0_data/EC166_B14.txt")
EC166_B28 = open("/Users/nathancahn/higher_order_ling/0_data/EC166_B28.txt")
EC166_B29 = open("/Users/nathancahn/higher_order_ling/0_data/EC166_B29.txt")
EC166_B34 = open("/Users/nathancahn/higher_order_ling/0_data/EC166_B34.txt")
EC166_B48 = open("/Users/nathancahn/higher_order_ling/0_data/EC166_B48.txt")

EC168_B7 = open("/Users/nathancahn/higher_order_ling/0_data/EC168_B7.txt")
EC168_B9 = open("/Users/nathancahn/higher_order_ling/0_data/EC168_B9.txt")
EC168_B10 = open("/Users/nathancahn/higher_order_ling/0_data/EC168_B10.txt")
EC168_B16 = open("/Users/nathancahn/higher_order_ling/0_data/EC168_B16.txt")
EC168_B20 = open("/Users/nathancahn/higher_order_ling/0_data/EC168_B20.txt")
EC168_B28 = open("/Users/nathancahn/higher_order_ling/0_data/EC168_B28.txt")
EC168_B37 = open("/Users/nathancahn/higher_order_ling/0_data/EC168_B37.txt")
EC168_B42 = open("/Users/nathancahn/higher_order_ling/0_data/EC168_B42.txt")
EC168_B45 = open("/Users/nathancahn/higher_order_ling/0_data/EC168_B45.txt")
EC168_B57 = open("/Users/nathancahn/higher_order_ling/0_data/EC168_B57.txt")
EC168_B69 = open("/Users/nathancahn/higher_order_ling/0_data/EC168_B69.txt")

EC169_B4 = open("/Users/nathancahn/higher_order_ling/0_data/EC169_B4.txt")
EC169_B10 = open("/Users/nathancahn/higher_order_ling/0_data/EC169_B10.txt")
EC169_B16 = open("/Users/nathancahn/higher_order_ling/0_data/EC169_B16.txt")
EC169_B19 = open("/Users/nathancahn/higher_order_ling/0_data/EC169_B19.txt")
EC169_B23 = open("/Users/nathancahn/higher_order_ling/0_data/EC169_B23.txt")
EC169_B32 = open("/Users/nathancahn/higher_order_ling/0_data/EC169_B32.txt")
EC169_B34 = open("/Users/nathancahn/higher_order_ling/0_data/EC169_B34.txt")
EC169_B38 = open("/Users/nathancahn/higher_order_ling/0_data/EC169_B38.txt")
EC169_B39 = open("/Users/nathancahn/higher_order_ling/0_data/EC169_B39.txt")

# %%
results_EC156_B8 = []
results_EC156_B9 = []
results_EC156_B22 = []
results_EC156_B25 = []
results_EC156_B27 = []
results_EC156_B32 = []
results_EC156_B37 = []
results_EC156_B38 = []
results_EC156_B46 = []
results_EC156_B55 = []
results_EC156_B56 = []
results_EC156_B67 = []

results_EC159_B3 = []
results_EC159_B17 = []

results_EC166_B11 = []
results_EC166_B14 = []
results_EC166_B28 = []
results_EC166_B29 = []
results_EC166_B34 = []
results_EC166_B48 = []

results_EC168_B7 = []
results_EC168_B9 = []
results_EC168_B10 = []
results_EC168_B16 = []
results_EC168_B20 = []
results_EC168_B28 = []
results_EC168_B37 = []
results_EC168_B42 = []
results_EC168_B45 = []
results_EC168_B57 = []
results_EC168_B69 = []

results_EC169_B4 = []
results_EC169_B10 = []
results_EC169_B16 = []
results_EC169_B19 = []
results_EC169_B23 = []
results_EC169_B32 = []
results_EC169_B34 = []
results_EC169_B38 = []
results_EC169_B39 = []

# %%
for i in EC156_B25:
    tokens = nltk.word_tokenize(i)
    tagged = nltk.pos_tag(tokens)
    results_EC156_B25.append(tokens)
    print(results_EC156_B25)
# Out:
# [['Uh', 'my', 'favorite', 'scene', 'Game', 'of', 'Thrones', '.']]
# [['Uh', 'my', 'favorite', 'scene', 'Game', 'of', 'Thrones', '.'], ['Well', 'there', "'s", 'more', 'than', 'one', 'favorite', 'scene', 'but', 'probably', '.']]
# [['Uh', 'my', 'favorite', 'scene', 'Game', 'of', 'Thrones', '.'], ['Well', 'there', "'s", 'more', 'than', 'one', 'favorite', 'scene', 'but', 'probably', '.'], ['right', 'now', 'the', 'one', 'that', 'pops', 'in', 'my', 'head', 'is', 'the', 'big', 'fella', 'holding', 'the', 'door', 'open', '.']]
# [['Uh', 'my', 'favorite', 'scene', 'Game', 'of', 'Thrones', '.'], ['Well', 'there', "'s", 'more', 'than', 'one', 'favorite', 'scene', 'but', 'probably', '.'], ['right', 'now', 'the', 'one', 'that', 'pops', 'in', 'my', 'head', 'is', 'the', 'big', 'fella', 'holding', 'the', 'door', 'open', '.'], ['cause', 'that', 'was', 'such', 'an', 'explainer', 'cause', 'I', 'just', 'I', 'did', "n't", 'know', '.']]
# ...

# %%
with open("/Users/nathancahn/higher_order_ling/2_pipeline/tmp/tag_EC156_B9.txt", "w") as output:
    output.write(str(results_EC156_B9))
